# %%
#import openai

# Configura tu clave API
#openai.api_key = "YOUR_API_KEY"



import os
from openai import OpenAI

# Pasa directamente la clave API al cliente
client = OpenAI(
    api_key="YOUR_API_KEY",  # Reemplaza esto con tu clave API
)

response = client.responses.create(
    model="gpt-4.1",  # Usa el modelo correcto
    instructions="Eres un asistente de codificación que habla como un pirata.",
    input="¿Cómo puedo verificar si un objeto de Python es una instancia de una clase?",
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 16
#      11 # Pasa directamente la clave API al cliente
#      12 client = OpenAI(
#      13     api_key="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",  # Reemplaza esto con tu clave API
#      14 )
# ---> 16 response = client.responses.create(
#      17     model="gpt-4.1",  # Usa el modelo correcto
#      18     instructions="Eres un asistente de codificación que habla como un pirata.",
#      19     input="¿Cómo puedo verificar si un objeto de Python es una instancia de una clase?",
#      20 )
#      22 print(response.output_text)
#
# ...
