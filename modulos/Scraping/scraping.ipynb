# %%
from sys import exit
import re
import calendar
import time
import os
import platform
import sys
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from selenium.common.exceptions import TimeoutException, NoSuchElementException
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains

# Configuración de opciones del navegador
chrome_options = Options()
chrome_options.add_argument("--disable-notifications")
chrome_options.add_argument("--disable-infobars")
chrome_options.add_argument("--mute-audio")
chrome_options.add_argument("--start-maximized")
# chrome_options.add_argument("headless")  # Descomenta si no deseas abrir el navegador

from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.common.exceptions import TimeoutException

def initialize_driver():
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument("--disable-notifications")
    chrome_options.add_argument("--disable-infobars")
    chrome_options.add_argument("--mute-audio")
    chrome_options.add_argument("--start-maximized")

    return webdriver.Chrome(options=chrome_options)

def login(driver):
    driver.get("https://websalud.minsa.gob.pe/hisminsa/")
    try:
        wait = WebDriverWait(driver, 10)
        # Espera hasta que los campos de usuario y contraseña estén presentes y visibles
        username_input = wait.until(EC.visibility_of_element_located((By.NAME, "mlkuser")))
        password_input = wait.until(EC.visibility_of_element_located((By.NAME, "mlkpass")))

        # Ingresar credenciales
        username_input.send_keys("46499644")
        password_input.send_keys("Irvin@12321")

        # Esperar 20 segundos
        time.sleep(15)

        # Hacer clic en el botón de login
        wait.until(EC.visibility_of_element_located((By.ID, "ext-gen1137"))).click()
       
        time.sleep(2)
        wait.until(EC.visibility_of_element_located((By.ID, "ext-gen1249"))).click()  
        print("SE ELIMINO LA VENTANA ") 

        print("BOTTON EXPORTAR") 
        #time.sleep(15)
        #element = wait.until(EC.visibility_of_element_located((By.ID, "ext-gen1296")))
        #element = wait.until(EC.visibility_of_element_located((By.ID, "ext-gen1784")))
        wait.until(EC.presence_of_element_located((By.XPATH, "//div[contains(@class, 'x-desktop-menu-item')]/span[text()='Exportar']"))).click()
        time.sleep(2)
        wait.until(EC.presence_of_element_located((By.XPATH, "//div[@class='x-desktop-menu-item x-desktop-submenu-item']/span[contains(text(), 'Exportar Reportes Varios')]"))).click()
        time.sleep(2)
        wait.until(EC.element_to_be_clickable((By.CLASS_NAME, 'x-form-trigger.x-form-search-trigger'))).click()
        time.sleep(2)
        # Espera a que la fila con el contenido específico sea visible
        content_to_click = "Archivo Plano Nuevo - Actualizado"  # Parte del contenido que es constante
        element_xpath = f"//td[contains(., '{content_to_click}')]"

        element = wait.until(EC.presence_of_element_located((By.XPATH, element_xpath)))
        # Haz doble clic en el elemento
        from selenium.webdriver.common.action_chains import ActionChains
        actions = ActionChains(driver)
        actions.double_click(element).perform()
        time.sleep(12)

        
        wait.until(EC.presence_of_element_located((By.XPATH, "//div[contains(@class, 'x-btn-default-toolbar-small')]/em/button/span/b[text()='Aceptar']"))).click()
        #WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, "//button/span[text()='Aceptar']]"))).click()

     
       


# Haz clic en el botón


       

# Haz clic en el elemento
        
     
      


        time.sleep(5)
    except TimeoutException:
        print("No se pudo encontrar uno de los elementos (mlkuser, mlkpass, ext-gen1137).")
        # Puedes manejar el error de acuerdo a tus necesidades
        time.sleep(5)

def main():
    try:
        driver = initialize_driver()
        login(driver)
    except Exception as e:
        print("Se produjo una excepción:", str(e))
    finally:
        # Cerrar el navegador
        if driver:
            driver.quit()

if __name__ == "__main__":
    main()

# %%
from selenium.webdriver.common.by import By
from selenium import webdriver

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--disable-notifications")
chrome_options.add_argument("--disable-infobars")
chrome_options.add_argument("--mute-audio")
chrome_options.add_argument("--start-maximized")

driver = webdriver.Chrome(options=chrome_options)

driver.get("https://websalud.minsa.gob.pe/hisminsa/")

# Espera hasta que los campos de usuario y contraseña estén presentes y visibles
wait = WebDriverWait(driver, 10)
username_input = wait.until(EC.visibility_of_element_located((By.NAME, "mlkuser")))
password_input = wait.until(EC.visibility_of_element_located((By.NAME, "mlkpass")))


# Ingresar credenciales
username_input.send_keys("46499644")
password_input.send_keys("Irvin@12321")


# Esperar 20 segundos
time.sleep(20)

button_input = wait.until(EC.visibility_of_element_located((By.ID, "ext-gen1137"))).click()

# Puedes agregar más acciones aquí después de iniciar sesión si es necesario

# Cerrar el navegador
driver.quit()

# %%
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

def login(username, password):
    # Inicializar el driver con undetected-chromedriver
    options = uc.ChromeOptions()
    options.add_argument("--disable-notifications")
    options.add_argument("--disable-infobars")
    options.add_argument("--mute-audio")
    options.add_argument("--start-maximized")
    #ptions.add_argument("--headless")  # Ahora se establece headless directamente como un argumento
    #options.headless = False
    

    driver = uc.Chrome(options=options)
    driver.get("https://websalud.minsa.gob.pe/hisminsa/")

    # Esperar a que el campo de usuario esté visible
    username_input = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.NAME, "mlkuser")))
    username_input.send_keys(username)

    # Esperar a que el campo de contraseña esté visible
    password_input = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.NAME, "mlkpass")))
    password_input.send_keys(password)

    # Hacer clic en el botón de iniciar sesión
    button_input = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.ID, "ext-gen1137")))
    button_input.click()

    # Esperar a que el botón de inicio esté visible y se pueda hacer clic en él
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.ID, "ext-gen1147")))

    # Cerrar el navegador
    driver.quit()

if __name__ == "__main__":
    username = "46499644"
    password = "Irvin@12321"
    login(username, password)

# %%
import requests
import json

me_url = '7-11-02-01--2418-20231107-20231107'

url = "https://gis.minsa.gob.pe/reporthis/his/NominalTramaNuevo.aspx"

data = {
    "C": "APP",
    "S": "INTEROP",
    "dato1": "7-11-02-01",
    "dato2": "2418-20231107-20231107",
    "nameuser": 46499644
}

response = requests.post(url, data=data)

if response.status_code == 200:
    response_data = response.json()
    if "codigo" in response_data:
        if response_data["codigo"] == "0000":
            me_url += '&u=46499644' + '&t=' + response_data["mensaje"]
        else:
            print(response_data["mensaje"])
    else:
        print('No se ha recibido un objeto válido')
else:
    print('Error en la solicitud:', response.status_code)

# %%
import paramiko
import os

def download_files_sftp(hostname, port, username, password, remote_path, local_path):
    try:
        # Crear el objeto SSHClient
        client = paramiko.SSHClient()
        client.set_missing_host_key_policy(paramiko.AutoAddPolicy())

        # Conectar al servidor SFTP
        client.connect(hostname, port, username, password)

        # Crear el objeto SFTPClient
        sftp = client.open_sftp()

        # Verificar si la ruta local existe, si no, crearla
        if not os.path.exists(local_path):os.makedirs(local_path)

        # Listar archivos remotos en el directorio
        remote_files = sftp.listdir(remote_path)

        # Descargar cada archivo remoto
        for remote_file in remote_files:
            remote_file_path = os.path.join(remote_path, remote_file)
            local_file_path = os.path.join(local_path, remote_file)
            sftp.get(remote_file_path, local_file_path)

        print("Descarga completa.")

    except Exception as e:
        print(f"Error durante la descarga: {e}")

    finally:
        # Cerrar la conexión
        if sftp:
            sftp.close()
        client.close()

# Configuramos los datos de conexión
host = "181.177.250.128"
port = 22
username = "usr_dhr_008"
password = "X3veTg8z62R74J"

# Ruta remota y local
remote_directory = "/data_cvs_nominal/2023/"
local_directory = "D:/Irvin/Irvin/Python/data/2023/csv"

# Llamar a la función para descargar archivos
download_files_sftp(host, port, username, password, remote_directory, local_directory)
# Out:
# Error durante la descarga: Garbage packet received
