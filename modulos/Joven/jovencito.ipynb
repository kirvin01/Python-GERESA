# %%
import pandas as pd
import numpy as np
import os
import glob as gb
pd.options.display.max_columns = None
pd.set_option('display.max_rows',200)

# %%
# ruta carpeta datos
ruta_datos = os.path.abspath("./../data/")
df_datos = pd.read_csv(ruta_datos+'/Hisminsa_2022/consolidados/df_consolidado_23-01-23.csv', encoding='UTF-8')
df_datos
# Out:
# /tmp/ipykernel_2554/2965751193.py:3: DtypeWarning: Columns (20,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_datos = pd.read_csv(ruta_datos+'/Hisminsa_2022/consolidados/df_consolidado_23-01-23.csv', encoding='UTF-8')
#             Id_Cita  Anio  Mes  Dia Fecha_Atencion  Id_Establecimiento  \
# 0         793527131  2022   12    1     2022-12-01                2351
# 1         793527131  2022   12    1     2022-12-01                2351
# 2         793527131  2022   12    1     2022-12-01                2351
# 3         793527131  2022   12    1     2022-12-01                2351
# 4         793527131  2022   12    1     2022-12-01                2351
# ...             ...   ...  ...  ...            ...                 ...
# 18738467  738841576  2022    2   28     2022-02-28                2489
# 18738468  738846479  2022    2   28     2022-02-28                2489
# 18738469  738846479  2022    2   28     2022-02-28                2489
# ...

# %%
df_joven = df_datos[df_datos['Anio_Actual_Paciente'].between(18,29)]
df_joven
# Out:
#             Id_Cita  Anio  Mes  Dia Fecha_Atencion  Id_Establecimiento  \
# 407       793736959  2022   12    1     2022-12-01                2288
# 408       793736959  2022   12    1     2022-12-01                2288
# 409       795998006  2022   12    4     2022-12-04                2288
# 410       795998006  2022   12    4     2022-12-04                2288
# 411       801916917  2022   12   14     2022-12-14                2288
# ...             ...   ...  ...  ...            ...                 ...
# 18738459  735386421  2022    2   28     2022-02-28                2489
# 18738460  735386421  2022    2   28     2022-02-28                2489
# 18738461  735421613  2022    2   28     2022-02-28                2489
# 18738462  735421811  2022    2   28     2022-02-28                2489
# 18738463  738841396  2022    2   28     2022-02-28                2489
#
#           Id_Ups Id_Condicion_Establecimiento Id_Condicion_Servicio  \
# ...

# %%
df_jov = df_joven[['Id_Cita','Anio','Mes','Dia','Fecha_Atencion','Id_Establecimiento','Id_Ups','Id_Paciente','Edad_Reg','Genero','Id_Tipo_Documento','Numero_Documento','Fecha_Nacimiento','Id_Etnia','Id_Pais','Tipo_Diagnostico', 'Codigo_Item','Id_Correlativo', 'Valor_Lab', 'Id_Correlativo_Lab', 'Id_Otra_Condicion','Fecha_Ultima_Regla','Id_Condicion_Establecimiento','Id_Condicion_Servicio']]
df_jov
# Out:
#             Id_Cita  Anio  Mes  Dia Fecha_Atencion  Id_Establecimiento  \
# 407       793736959  2022   12    1     2022-12-01                2288
# 408       793736959  2022   12    1     2022-12-01                2288
# 409       795998006  2022   12    4     2022-12-04                2288
# 410       795998006  2022   12    4     2022-12-04                2288
# 411       801916917  2022   12   14     2022-12-14                2288
# ...             ...   ...  ...  ...            ...                 ...
# 18738459  735386421  2022    2   28     2022-02-28                2489
# 18738460  735386421  2022    2   28     2022-02-28                2489
# 18738461  735421613  2022    2   28     2022-02-28                2489
# 18738462  735421811  2022    2   28     2022-02-28                2489
# 18738463  738841396  2022    2   28     2022-02-28                2489
#
#           Id_Ups   Id_Paciente  Edad_Reg Genero  Id_Tipo_Documento  \
# ...

# %% [markdown]
# ## Examen Odontologico No Gestantes Inician

# %%
#df_jovF = df_jov[(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D1310','D1330','D0120','D1110']))&(df_jov.Valor_Lab.isin(['1']))&(df_jov.Id_Otra_Condicion.isin([2,np.nan]))&(~(df_jov.Valor_Lab.isin(['G'])))]
#df_jovF = df_jov[(df_jov.Genero=='F')&(df_jov.Id_Condicion_Establecimiento=='C')&(df_jov.Id_Condicion_Servicio=='N')&(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D1310','D1330','D0120','D1110']))&(df_jov.Valor_Lab.isin(['1']))&(~(df_jov.Valor_Lab.isin(['G'])))]
# calcula alta basica odontologica no gestantes
#df_jovF = df_jov[(df_jov.Genero=='F')&(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D1310','D1330','D0120','D1110']))&(df_jov.Valor_Lab.isin(['1']))&(~(df_jov.Valor_Lab.isin(['G'])))]
#ok
#df_jovF1 = df_jov[(df_jov.Genero=='F')&(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D0150','D1310','D1330','D0120','D1110']))&(df_jov.Valor_Lab.isin(['1']))&(df_jov.Id_Otra_Condicion.isin([2,np.nan]))]
df_jovF = df_jov[(df_jov.Genero=='F')&(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D0150','D0120']))&(df_jov.Valor_Lab.isin(['1']))&(~(df_jov.Valor_Lab.isin(['G'])))&(df_jov.Id_Otra_Condicion.isin([2,np.nan]))&(df_jov.Fecha_Ultima_Regla.isnull())]
df_jovF
# Out:
#             Id_Cita  Anio  Mes  Dia Fecha_Atencion  Id_Establecimiento  \
# 1825      665637612  2022    3   22     2022-03-22                2288
# 8119      631312903  2022    1    6     2022-01-06                2420
# 12719     742085308  2022    8    5     2022-08-05                2409
# 14365     759877044  2022    9   14     2022-09-14                2305
# 27913     792324899  2022   11   28     2022-11-28                2363
# ...             ...   ...  ...  ...            ...                 ...
# 18718589  653611704  2022    2   25     2022-02-25                2304
# 18719494  654998382  2022    2   25     2022-02-25                2468
# 18724092  652020926  2022    2   26     2022-02-26                2363
# 18726503  654673131  2022    2   26     2022-02-26                2289
# 18726955  656826155  2022    2   26     2022-02-26                2400
#
#           Id_Ups   Id_Paciente  Edad_Reg Genero  Id_Tipo_Documento  \
# ...

# %%
x = df_jovF.pivot_table(index=['Id_Cita','Anio','Mes','Dia','Fecha_Atencion','Id_Establecimiento','Id_Ups','Id_Paciente','Edad_Reg','Genero','Id_Tipo_Documento','Numero_Documento','Fecha_Nacimiento','Id_Etnia','Id_Pais'], columns=[], values=['Codigo_Item','Valor_Lab'], aggfunc='sum').reset_index()
x
# Out:
#         Id_Cita  Anio  Mes  Dia Fecha_Atencion  Id_Establecimiento  Id_Ups  \
# 0     619057989  2022    1    3     2022-01-03                2519  303304
# 1     620230790  2022    1    4     2022-01-04                2519  303304
# 2     620743588  2022    1    4     2022-01-04                2324  303304
# 3     620747848  2022    1    4     2022-01-04                2324  303304
# 4     620755997  2022    1    5     2022-01-05                2324  303304
# ...         ...   ...  ...  ...            ...                 ...     ...
# 7348  814466398  2023    1    6     2023-01-06                2377  303304
# 7349  814467964  2023    1    7     2023-01-07                2377  303304
# 7350  814480101  2023    1   12     2023-01-12                2377  303304
# 7351  814481053  2023    1   12     2023-01-12                2377  303304
# 7352  814485070  2023    1   13     2023-01-13                2377  303304
#
# ...

# %%
# y = x[(x.Valor_Lab.str.contains('G',na=False)) ]
# y

# %%
# y = x[(x.Codigo_Item.str.contains('U510',na=False))  | (x.Valor_Lab.str.contains('ABO',na=False)) ]
# y

# %%
# y = x[(x.Codigo_Item[1].str.contains('U510',na=False)) | (x.Codigo_Item[2].str.contains('U510',na=False)) | (x.Valor_Lab[1].str.contains('ABO',na=False)) | (x.Valor_Lab[2].str.contains('ABO',na=False))]
# y

# %%
# df_jovDX = df_jovF[['Id_Cita', 'Anio','Mes','Dia','Id_Paciente','Codigo_Item','Id_Correlativo']]
# df_jovDX

# %%
# df_jovPdx = df_jovDX.pivot(index=['Id_Cita','Anio','Mes','Dia','Id_Paciente'], columns=['Id_Correlativo'], values=['Codigo_Item']).reset_index()
# df_jovPdx

# %%
# df_jovLab = df_jovF[['Id_Cita','Anio','Mes','Dia','Id_Paciente','Valor_Lab', 'Id_Correlativo_Lab']]
# df_jovLab

# %%
# df_jovPLab = df_jovLab.pivot_table(index=['Id_Cita','Anio','Mes','Dia','Id_Paciente'], columns=['Id_Correlativo_Lab'], values=['Valor_Lab'], aggfunc='sum').reset_index()
# df_jovPLab

# %%
# union de diagnosticos y pacientes
# df_jovDxLab = pd.merge(df_jovPdx, df_jovPLab, on=['Id_Cita','Anio','Mes','Dia','Id_Paciente'],how='inner')
# df_jovDxLab

# %%
# df_jovDxLab = df_jovDxLab[(df_jovDxLab.Valor_Lab[1].str.contains('ABO',na=False)) | (df_jovDxLab.Valor_Lab[2].str.contains('ABO',na=False))]
# df_jovDxLab

# %%
# unir con la tabla inicial
# df_jovenNoGesInician = pd.merge(y, df_joven, on=['Id_Cita','Anio','Mes','Dia'],how='inner')
# df_jovenNoGesInician

# %%
df2 = x.groupby(['Anio','Mes'])['Id_Cita'].agg(['count']).reset_index()
df2
# Out:
#     Anio  Mes  count
# 0   2022    1    982
# 1   2022    2   1019
# 2   2022    3   1169
# 3   2022    4    886
# 4   2022    5    708
# 5   2022    6    383
# 6   2022    7    337
# 7   2022    8    418
# 8   2022    9    367
# 9   2022   10    324
# 10  2022   11    322
# 11  2022   12    246
# 12  2023    1    192

# %% [markdown]
# ## examen odontologico No Gestantes caso tratado

# %%
#df_jovF = df_jov[(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D1310','D1330','D0120','D1110']))&(df_jov.Valor_Lab.isin(['1']))&(df_jov.Id_Otra_Condicion.isin([2,np.nan]))&(~(df_jov.Valor_Lab.isin(['G'])))]
#df_jovF = df_jov[(df_jov.Genero=='F')&(df_jov.Id_Condicion_Establecimiento=='C')&(df_jov.Id_Condicion_Servicio=='N')&(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D1310','D1330','D0120','D1110']))&(df_jov.Valor_Lab.isin(['1']))&(~(df_jov.Valor_Lab.isin(['G'])))]
# calcula alta basica odontologica no gestantes
#df_jovF = df_jov[(df_jov.Genero=='F')&(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D1310','D1330','D0120','D1110']))&(df_jov.Valor_Lab.isin(['1']))&(~(df_jov.Valor_Lab.isin(['G'])))]
#ok
#df_jovF = df_jov[(df_jov.Genero=='F')&(df_jov.Id_Condicion_Servicio.isin(['N']))&(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D1310','D1330','D0120','D1110']))&(df_jov.Valor_Lab.isin(['1']))&(~(df_jov.Valor_Lab.isin(['G'])))]
df_jovF = df_jov[(df_jov.Genero=='F')&(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D0120','D1330','D1310','D1110','U510']))&(df_jov.Valor_Lab.isin(['2','ABO']))&(~(df_jov.Valor_Lab.isin(['G'])))&(df_jov.Id_Otra_Condicion.isin([2,np.nan]))]
df_jovF
# Out:
#             Id_Cita  Anio  Mes  Dia Fecha_Atencion  Id_Establecimiento  \
# 8074      668481456  2022    3    9     2022-03-09                2420
# 8075      668481456  2022    3    9     2022-03-09                2420
# 12725     742085308  2022    8    5     2022-08-05                2409
# 27889     800356668  2022   12   15     2022-12-15                2363
# 43296     796571812  2022   12    1     2022-12-01                2524
# ...             ...   ...  ...  ...            ...                 ...
# 18629621  646122734  2022    2   18     2022-02-18                7111
# 18629622  646122734  2022    2   18     2022-02-18                7111
# 18687809  654266397  2022    2   25     2022-02-25               21902
# 18687815  654266397  2022    2   25     2022-02-25               21902
# 18687816  654266397  2022    2   25     2022-02-25               21902
#
#           Id_Ups   Id_Paciente  Edad_Reg Genero  Id_Tipo_Documento  \
# ...

# %%
x = df_jovF.pivot_table(index=['Id_Cita','Anio','Mes','Dia','Fecha_Atencion','Id_Establecimiento','Id_Ups','Id_Paciente','Edad_Reg','Genero','Id_Tipo_Documento','Numero_Documento','Fecha_Nacimiento','Id_Etnia','Id_Pais'], columns=[], values=['Codigo_Item','Valor_Lab'], aggfunc='sum').reset_index()
x
# Out:
#         Id_Cita  Anio  Mes  Dia Fecha_Atencion  Id_Establecimiento  Id_Ups  \
# 0     620223499  2022    1    4     2022-01-04                2519  303304
# 1     620227897  2022    1    4     2022-01-04                2519  303304
# 2     621506066  2022    1    3     2022-01-03                2384  303304
# 3     621567078  2022    1    6     2022-01-06                2300  303304
# 4     621649273  2022    1    6     2022-01-06                2300  303304
# ...         ...   ...  ...  ...            ...                 ...     ...
# 5581  814424412  2023    1    9     2023-01-09                2464  303304
# 5582  814430725  2023    1   12     2023-01-12                2320  303304
# 5583  814669639  2023    1   17     2023-01-17                2541  303304
# 5584  814725997  2023    1   16     2023-01-16                2403  303304
# 5585  814855659  2023    1    2     2023-01-02                2309  303304
#
# ...

# %%
y = x[(x.Codigo_Item.str.contains('U510',na=False))|((x.Valor_Lab.str.contains('ABO',na=False)))|(x.Valor_Lab.str.contains('2',na=False))]
y
# Out:
#         Id_Cita  Anio  Mes  Dia Fecha_Atencion  Id_Establecimiento  Id_Ups  \
# 0     620223499  2022    1    4     2022-01-04                2519  303304
# 1     620227897  2022    1    4     2022-01-04                2519  303304
# 2     621506066  2022    1    3     2022-01-03                2384  303304
# 3     621567078  2022    1    6     2022-01-06                2300  303304
# 4     621649273  2022    1    6     2022-01-06                2300  303304
# ...         ...   ...  ...  ...            ...                 ...     ...
# 5581  814424412  2023    1    9     2023-01-09                2464  303304
# 5582  814430725  2023    1   12     2023-01-12                2320  303304
# 5583  814669639  2023    1   17     2023-01-17                2541  303304
# 5584  814725997  2023    1   16     2023-01-16                2403  303304
# 5585  814855659  2023    1    2     2023-01-02                2309  303304
#
# ...

# %%
dfCT = y.groupby(['Anio','Mes'])['Id_Cita'].agg(['count']).reset_index()
dfCT
# Out:
#     Anio  Mes  count
# 0   2022    1    274
# 1   2022    2    352
# 2   2022    3    448
# 3   2022    4    450
# 4   2022    5    516
# 5   2022    6    514
# 6   2022    7    440
# 7   2022    8    547
# 8   2022    9    522
# 9   2022   10    495
# 10  2022   11    527
# 11  2022   12    403
# 12  2023    1     98

# %% [markdown]
# ## Examen Odontologico Gestantes Inician

# %%
df_jovGI = df_jov[(df_jov.Id_Condicion_Establecimiento.isin(['C']))&(df_jov.Id_Condicion_Servicio.isin(['N']))&(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D0150','D0120','D1330','D1310']))&(df_jov.Valor_Lab.isin(['1','G']))]
df_jovGI

# %%
x = df_jovGI.pivot_table(index=['Id_Cita','Anio','Mes','Dia','Fecha_Atencion','Id_Establecimiento','Id_Ups','Id_Paciente','Edad_Reg','Genero','Id_Tipo_Documento','Numero_Documento','Fecha_Nacimiento','Id_Etnia','Id_Pais'], columns=[], values=['Codigo_Item','Valor_Lab'], aggfunc='sum').reset_index()
x

# %%
y = x[(x.Valor_Lab.str.contains('G',na=False)) ]
y

# %%
dfGI = y.groupby(['Anio','Mes'])['Id_Cita'].agg(['count']).reset_index()
dfGI

# %% [markdown]
# # Examen odontologico gestantes caso tratado

# %%
df_jovGCT = df_jov[(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D0150','D0120','D1330','D1310','D1110','U510']))&(df_jov.Valor_Lab.isin(['2','G','ABO']))]
df_jovGCT

# %%
x = df_jovGCT.pivot_table(index=['Id_Cita','Anio','Mes','Dia','Fecha_Atencion','Id_Establecimiento','Id_Ups','Id_Paciente','Edad_Reg','Genero','Id_Tipo_Documento','Numero_Documento','Fecha_Nacimiento','Id_Etnia','Id_Pais'], columns=[], values=['Codigo_Item','Valor_Lab'], aggfunc='sum').reset_index()
x

# %%
y = x[(x.Codigo_Item.str.contains('U510',na=False))  | (x.Valor_Lab.str.contains('ABO',na=False)) ]
y

# %%
dfGCT = y.groupby(['Anio','Mes'])['Id_Cita'].agg(['count']).reset_index()
dfGCT

# %% [markdown]
# # instrucciones de higiene oral inician

# %%
df_jovIHO = df_jov[(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D1330','U540']))&(df_jov.Valor_Lab.isin(['1']))]
df_jovIHO

# %%
x = df_jovIHO.pivot_table(index=['Id_Cita','Anio','Mes','Dia','Fecha_Atencion','Id_Establecimiento','Id_Ups','Id_Paciente','Edad_Reg','Genero','Id_Tipo_Documento','Numero_Documento','Fecha_Nacimiento','Id_Etnia','Id_Pais'], columns=[], values=['Codigo_Item','Valor_Lab'], aggfunc='sum').reset_index()
x

# %%
dfIHO = x.groupby(['Anio','Mes'])['Id_Cita'].agg(['count']).reset_index()
dfIHO

# %% [markdown]
# # instrucciones de higiene oral tratado

# %%
df_jovIHOT = df_jov[(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D1330','U540']))&(df_jov.Valor_Lab.isin(['2']))]
df_jovIHOT

# %%
x = df_jovIHOT.pivot_table(index=['Id_Cita','Anio','Mes','Dia','Fecha_Atencion','Id_Establecimiento','Id_Ups','Id_Paciente','Edad_Reg','Genero','Id_Tipo_Documento','Numero_Documento','Fecha_Nacimiento','Id_Etnia','Id_Pais'], columns=[], values=['Codigo_Item','Valor_Lab'], aggfunc='sum').reset_index()
x

# %%
dfIHOt = x.groupby(['Anio','Mes'])['Id_Cita'].agg(['count']).reset_index()
dfIHOt

# %% [markdown]
# ## Asesoría nutricional para el control de enfermedades dentales inician

# %%
df_jovANi = df_jov[(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D1310']))&(df_jov.Valor_Lab.isin(['1']))]
df_jovANi

# %%
x = df_jovANi.pivot_table(index=['Id_Cita','Anio','Mes','Dia','Fecha_Atencion','Id_Establecimiento','Id_Ups','Id_Paciente','Edad_Reg','Genero','Id_Tipo_Documento','Numero_Documento','Fecha_Nacimiento','Id_Etnia','Id_Pais'], columns=[], values=['Codigo_Item','Valor_Lab'], aggfunc='sum').reset_index()
x

# %%
dfANi = x.groupby(['Anio','Mes'])['Id_Cita'].agg(['count']).reset_index()
dfANi

# %% [markdown]
# ## Asesoría nutricional para el control de enfermedades dentales caso tratado

# %%
df_jovANct = df_jov[(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['D1310']))&(df_jov.Valor_Lab.isin(['2']))]
df_jovANct

# %%
x = df_jovANct.pivot_table(index=['Id_Cita','Anio','Mes','Dia','Fecha_Atencion','Id_Establecimiento','Id_Ups','Id_Paciente','Edad_Reg','Genero','Id_Tipo_Documento','Numero_Documento','Fecha_Nacimiento','Id_Etnia','Id_Pais'], columns=[], values=['Codigo_Item','Valor_Lab'], aggfunc='sum').reset_index()
x

# %%
dfANct = x.groupby(['Anio','Mes'])['Id_Cita'].agg(['count']).reset_index()
dfANct

# %% [markdown]
# ## Alta Basica Odontologica no gestantes

# %%
G=[]

# %%
df_jovABOng = df_jov[(df_jov.Genero.isin(G)if G else True)&(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['U510']))&(df_jov.Valor_Lab.isin([np.nan]))&(~(df_jov.Valor_Lab=='G'))&(df_jov.Id_Otra_Condicion.isin([2,np.nan]))]
df_jovABOng
# Out:
#             Id_Cita  Anio  Mes  Dia Fecha_Atencion  Id_Establecimiento  \
# 76618     810294090  2023    1    3     2023-01-03                2322
# 108922    713511765  2022    6    8     2022-06-08                2320
# 108941    753467129  2022    8   25     2022-08-25                2320
# 109047    732489606  2022    7   15     2022-07-15                2320
# 110688    787555035  2022   11   16     2022-11-16                2547
# ...             ...   ...  ...  ...            ...                 ...
# 18503074  648099367  2022    2   21     2022-02-21                2299
# 18516413  645795353  2022    2   10     2022-02-10                2288
# 18526387  650361526  2022    2   24     2022-02-24                2494
# 18570736  650424898  2022    2    9     2022-02-09                2447
# 18687817  654266397  2022    2   25     2022-02-25               21902
#
#           Id_Ups   Id_Paciente  Edad_Reg Genero  Id_Tipo_Documento  \
# ...

# %%
x = df_jovABOng.pivot_table(index=['Id_Cita','Anio','Mes','Dia','Fecha_Atencion','Id_Establecimiento','Id_Ups','Id_Paciente','Edad_Reg','Genero','Id_Tipo_Documento','Numero_Documento','Fecha_Nacimiento','Id_Etnia','Id_Pais'], columns=[], values=['Codigo_Item','Valor_Lab'], aggfunc='sum').reset_index()
x
# Out:
#         Id_Cita  Anio  Mes  Dia Fecha_Atencion  Id_Establecimiento  Id_Ups  \
# 0     620223499  2022    1    4     2022-01-04                2519  303304
# 1     620227897  2022    1    4     2022-01-04                2519  303304
# 2     626838501  2022    1   12     2022-01-12                2300  303304
# 3     626904786  2022    1    8     2022-01-08                2300  303304
# 4     627051561  2022    1   11     2022-01-11                2315  303304
# ...         ...   ...  ...  ...            ...                 ...     ...
# 1585  813876591  2023    1   17     2023-01-17                2522  303304
# 1586  813963192  2023    1    8     2023-01-08                2359  303304
# 1587  813972501  2023    1   14     2023-01-14                2359  303304
# 1588  814332016  2023    1    9     2023-01-09                2377  303304
# 1589  814536103  2023    1   16     2023-01-16                2302  303304
#
# ...

# %%
dfABO = x.groupby(['Anio','Mes'])['Id_Cita'].agg(['count']).reset_index()
dfABO
# Out:
#     Anio  Mes  count
# 0   2022    1     46
# 1   2022    2     55
# 2   2022    3     82
# 3   2022    4    120
# 4   2022    5    124
# 5   2022    6    152
# 6   2022    7    146
# 7   2022    8    166
# 8   2022    9    201
# 9   2022   10    160
# 10  2022   11    160
# 11  2022   12    152
# 12  2023    1     26

# %%
## Alta Basica Odontologica gestantes

# %%
df_jovABOg = df_jov[(df_jov.Genero=='F')&(df_jov.Tipo_Diagnostico.isin(['D']))&(df_jov.Codigo_Item.isin(['U510']))&(df_jov.Valor_Lab.isin(['G','ABO',np.nan]))]
df_jovABOg

# %%
x = df_jovABOg.pivot_table(index=['Id_Cita','Anio','Mes','Dia','Fecha_Atencion','Id_Establecimiento','Id_Ups','Id_Paciente','Edad_Reg','Genero','Id_Tipo_Documento','Numero_Documento','Fecha_Nacimiento','Id_Etnia','Id_Pais'], columns=['Id_Correlativo_Lab'], values=['Codigo_Item','Valor_Lab'], aggfunc='sum').reset_index()
x

# %%
dfABO = x.groupby(['Anio','Mes'])['Id_Cita'].agg(['count']).reset_index()
dfABO

# %% [markdown]
# # DETECCION DE ENFERMEDADES NO TRANSMISIBLES EN JOVENES

# %% [markdown]
# ## Valoración Clinica de Factores de Riesgo

# %%
td = ['D']
dx = ['Z019']
lab = ['DNT']
G = ['F']

# %%
df_jovVCFR = df_jov[(df_jov.Genero.isin(G)if G else True)&(df_jov.Tipo_Diagnostico.isin(td)if td else True)&(df_jov.Codigo_Item.isin(dx)if dx else True)&(df_jov.Valor_Lab.isin(lab)if lab else True)]
df_jovVCFR
# Out:
#             Id_Cita  Anio  Mes  Dia Fecha_Atencion  Id_Establecimiento  \
# 25555     760050883  2022    9   16     2022-09-16               17424
# 29816     685029187  2022    4   28     2022-04-28                2401
# 34835     802658097  2022   12   20     2022-12-20                9691
# 35711     796305145  2022   12    1     2022-12-01                9689
# 37219     700205900  2022    5   22     2022-05-22                6960
# ...             ...   ...  ...  ...            ...                 ...
# 18721340  677906670  2022    2   25     2022-02-25                2330
# 18722273  652129803  2022    2   26     2022-02-26                2300
# 18730663  655701421  2022    2   27     2022-02-27                2478
# 18731061  652288209  2022    2   28     2022-02-28               23681
# 18731795  653509310  2022    2   28     2022-02-28                2290
#
#           Id_Ups    Id_Paciente  Edad_Reg Genero  Id_Tipo_Documento  \
# ...

# %%
x = df_jovVCFR.pivot_table(index=['Id_Cita','Anio','Mes','Dia','Fecha_Atencion','Id_Establecimiento','Id_Ups','Id_Paciente','Edad_Reg','Genero','Id_Tipo_Documento','Numero_Documento','Fecha_Nacimiento','Id_Etnia','Id_Pais'], columns=['Id_Correlativo_Lab'], values=['Codigo_Item','Valor_Lab'], aggfunc='sum').reset_index()
x
# Out:
#                       Id_Cita  Anio Mes Dia Fecha_Atencion Id_Establecimiento  \
# Id_Correlativo_Lab
# 0                   619954471  2022   1   3     2022-01-03               2499
# 1                   621401535  2022   1   3     2022-01-03               2384
# 2                   621402551  2022   1   3     2022-01-03               2384
# 3                   621407853  2022   1   3     2022-01-03               2384
# 4                   621499310  2022   1   6     2022-01-06               2324
# ...                       ...   ...  ..  ..            ...                ...
# 17652               814761703  2023   1  12     2023-01-12               2350
# 17653               814819331  2023   1  18     2023-01-18               9691
# 17654               814842571  2023   1  14     2023-01-14               6952
# 17655               814842779  2023   1  14     2023-01-14               6952
# 17656               814842991  2023   1  16     2023-01-16               6952
#
# ...

# %%
dfVCFR = x.groupby(['Anio','Mes'])['Id_Cita'].agg(['count']).reset_index()
dfVCFR
# Out:
#     Anio  Mes  count
# 0   2022    1    943
# 1   2022    2   1138
# 2   2022    3   1743
# 3   2022    4   1647
# 4   2022    5   3216
# 5   2022    6   1567
# 6   2022    7   1028
# 7   2022    8    802
# 8   2022    9    929
# 9   2022   10   1390
# 10  2022   11   1575
# 11  2022   12   1213
# 12  2023    1    466
